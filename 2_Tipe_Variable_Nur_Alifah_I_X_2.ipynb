# %% [markdown]
# <a href="https://colab.research.google.com/github/nuralifahizzaty2025-ctrl/KKA-X-Semester-1-Nur_Alifah/blob/main/2_Tipe_Variable_Nur_Alifah_I_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Nur Alifah Izzaty
#
# Kelas : X.2
#
# No.Absen : 25

# %% [markdown]
# #Konsep Dasar Variable

# %%
print("alifaa.izz09.@gmail.com")
print("alifaa.izz09.@gmail.com")
print("alifaa.izz09.@gmail.com")
# Out:
# alifaa.izz09.@gmail.com
# alifaa.izz09.@gmail.com
# alifaa.izz09.@gmail.com

# %%
email_user = "alifaa.izz09.@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# alifaa.izz09.@gmail.com
# alifaa.izz09.@gmail.com
# alifaa.izz09.@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variable

# %%
#Hanya boleh menggunakan huruf, angka, dan underscore
harga telur = 15000
print(harga_telur)
# Out:
#   File "/tmp/ipython-input-3861187382.py", line 2
#     harga telur = 15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
#Tidak boleh diawali dengan angka
1_nama_siswa = "Ahmad Dhani"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-827145144.py", line 2
#     1_nama_siswa = "Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
nama_siswa_1 = "Ahmad Dhani"
print(nama_siswa_1)
# Out:
# Ahmad Dhani

# %%
#Tidak boleh menggunakan kata kunci python
if = "Handayani"
print(if)
# Out:
#   File "/tmp/ipython-input-3203481015.py", line 2
#     if = "Handayani"
#        ^
# SyntaxError: invalid syntax

# %%
If = "Handayani"
print(If)
# Out:
# Handayani

# %%
print = "Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2451231669.py in <cell line: 0>()
#       1 print = "Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
#Sensitif terhadap penulisan kapital
USIA = 17
print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1011207708.py in <cell line: 0>()
#       1 #Sensitif terhadap penulisan kapital
#       2 USIA = 17
# ----> 3 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "Fazel Wardana"

# %%
_ = "Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# #Assignment

# %%
#Single assignment
bb_fazel = 55
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#Multiple assignment
bb_fazel, bb_dani = 55,60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani = 55,60,70

print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-35283741.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani = 55,60,70
#       2
#       3 print(bb_dani)
#       4 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1, nama_siswa_2 = "deni", "doni"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel, bb_dani, bb_adli = 55,60
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-272119192.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli = 55,60
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#Chain siggnment
bb_hasbi = bb_dani = 60
print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# #Cara penulisan operatorpada phyton

# %%
#Tanpa variable
print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#Operand disimpan ke variable
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#Hasil operasi disimpan ke variable
total_hp = 10 + 6

print(total_hp)
# Out:
# 16

# %%
#Operasi dan hasil operasi disimpan ke variable
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

total_hp = jumlah_hp_habibi + jumlah_hp_syauqi

print(total_hp)
# Out:
# 16

# %%
#Single assignment
nama = "Andi"

print(nama)
# Out:
# Andi

# %%
#Multipleassignment
nama,umur, kelas = "Budi", 15, "9A"

# %%
roti = 22
tamu = 4
print(roti//tamu)
# Out:
# 5

# %%
roti = 23
tamu = 4
sisa_bagi_roti_tamu = roti % tamu
print(

# %%
nama = "alifah"
Nama = "nur"
NAMA =izza
print(nama)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3948061225.py in <cell line: 0>()
# ----> 1 nama = alifah
#       2 Nama = nur
#       3 NAMA =izza
#       4 print(nama)
#
# NameError: name 'alifah' is not defined

# %% [markdown]
# #Jenis–jenis Tipe Variable

# %%
a = "Faris"

print(a)
type(a)
# Out:
# Faris
# str

# %%
b = 9.9

print(b)
type(b)
# Out:
# 9.9
# float

# %%
c =0

print(c)
type(c)
# Out:
# 0
# int

# %%
d = true

print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3042645456.py in <cell line: 0>()
# ----> 1 d = true
#       2
#       3 print(d)
#       4 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True

print(d)
type(d)
# Out:
# True
# bool

# %%
f = "False"

print(f)
type(f)
# Out:
# False
# str

# %%
g = 9,2

print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("rendra")
# Out:
# str

# %%
type(-9.1)
# Out:
# float

# %% [markdown]
# #Mengubah Bentuk Variable

# %%
a = 5

print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(a)

print(a)
type(a)
# Out:
# 5.0
# float

# %% [markdown]
# #Operator Perbandingan

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 < 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2 )
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1 ))
# Out:
# True

# %%
print(not(5 < 10 or 5 <=10))
# Out:
# False
