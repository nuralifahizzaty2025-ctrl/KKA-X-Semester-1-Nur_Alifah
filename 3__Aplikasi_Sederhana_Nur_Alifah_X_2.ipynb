# %% [markdown]
# <a href="https://colab.research.google.com/github/nuralifahizzaty2025-ctrl/KKA-X-Semester-1-Nur_Alifah/blob/main/3__Aplikasi_Sederhana_Nur_Alifah_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nama Kelompok : 6
# #Nama : Nur alifah izzaty
# #Kelas:X.2
# #Nomer Absen : 25

# %% [markdown]
# # Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang = int(input ("masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# masukkan panjang dari persegi panjang (cm): 5
# masukkan lebar dari persegi panjang (cm): 4
#
# Luas dari persegi panjang yaitu 20 cm^2

# %%
panjang = int(input ("masukkan panjang dari balok (cm): "))
lebar = int(input("masukkan lebar dari balok (cm): "))
tinggi = int(input("masukkan tinggi dari balok(cm): "))

volume = panjang * lebar * tinggi
luas = 2 * panjang * lebar + 2 * panjang * tinggi + 2 * lebar * tinggi

print(f"\nvolume dari balok yaitu {volume} cm^3")
print(f"\nluas dari balok yaitu {luas} cm^2")
# Out:
# masukkan panjang dari balok (cm): 6
# masukkan lebar dari balok (cm): 5
# masukkan tinggi dari balok(cm): 5
#
# volume dari balok yaitu 150 cm^3
#
# luas dari balok yaitu 170 cm^2
